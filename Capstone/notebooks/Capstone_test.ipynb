# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
outcomes = ["Head", "Tail"]

# %%
num_flip_trials = [10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000, 5000000, 10000000, 50000000, 100000000, 500000000, 1000000000]

# %%
Prob_heads = []
for flip in num_flip_trials:
    head_count = 0
    for _ in range(flip):
        if random.choice(outcomes) == "Head":
            head_count += 1
    Prob_heads.append(head_count / flip)
    print(f"Prob (Head) = {Prob_heads[-1]}" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 head_count = 0
#       4 for _ in range(flip):
# ----> 5     if random.choice(outcomes) == "Head":
#       6         head_count += 1
#       7 Prob_heads.append(head_count / flip)
#
# NameError: name 'random' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(
    x=num_flip_trials,
    y=Prob_heads,
    marker='o',
    color='red',
    s=60,
    alpha=0.7,
    ax=ax
)

ax.set_xscale('log')
ax.axhline(0.5, color='gray', linestyle='--', label='Expected Probability (0.5)')
ax.set_title("Probability of Heads vs Number of Coin Flips", fontsize=14)
ax.set_xlabel("Number of Flips (log scale)", fontsize=12)
ax.set_ylabel("Probability of Heads", fontsize=12)
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.legend()
plt.tight_layout()
plt.savefig("better-flip-plot.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 6))
if Prob_heads:
    sns.lineplot(
        x=num_flip_trials,
        y=Prob_heads,
        marker='o',
        color='red',
        ax=ax
    )
else:
    print("Prob_heads is empty. Please generate data before plotting.")

ax.set_xscale('log')
ax.axhline(0.5, color='gray', linestyle='--', label='Expected Probability (0.5)')
ax.set_title("Probability of Heads vs Number of Coin Flips", fontsize=14)
ax.set_xlabel("Number of Flips (log scale)", fontsize=12)
ax.set_ylabel("Probability of Heads", fontsize=12)
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.legend()
plt.tight_layout()
plt.savefig("better-flip-plot.png")
plt.show()
# Out:
# Prob_heads is empty. Please generate data before plotting.
